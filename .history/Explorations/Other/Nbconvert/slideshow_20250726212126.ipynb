# %% [markdown]
# # Welcome to the Presentation
#
# This is a Jupyter Notebook rendered as a Reveal.js slide deck.

# %% [markdown]
# ## Agenda
#
# - Motivation
# - Methodology
# - Results
# - Conclusion

# %% [markdown]
# ## Motivation
#
# Why are we doing this?
# - Need for transparency
# - Reproducibility
# - Communicating results

# %%
# A simple plot
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("Sine Wave")
plt.show()

# %% [markdown]
# ## Methodology
#
# 1. Data Collection
# 2. Preprocessing
# 3. Modeling
# 4. Evaluation

# %% [markdown]
# ## Conclusion
#
# - Jupyter + Reveal.js offers a flexible, code-integrated presentation format.
# - Great for teaching, demos, and reproducible research.
#
# **Thank you!**
